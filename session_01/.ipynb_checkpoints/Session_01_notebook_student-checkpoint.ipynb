# %% [markdown]
# <div style='background: #FF7B47; padding: 10px; border: thin solid darblue; border-radius: 5px; margin-bottom: 2vh'>
#
# # Session 01 - Notebook
#
# Like most session notebooks in this course, this notebook is divided into two parts. Part one is a 'manual' that will allow you to code along with the new code that we introduce at the beginning of each session. The second part is the actual lab/assignment part, where you will work through a few practical tasks and write small but useful programs.

# %% [markdown]
# <div style='background: #FF7B47; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Part 1 -  Manual

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.1 - "hello, world!"

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.2 - basic datatypes - strings and numeric variables

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.3 - basic operations

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.4 - advanced data types to store collections of data

# %%
# your code here - dictionaries
my_dictionary = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964, 
    "cities_exhibited": ["Madrid", "Munich", "Boston"]
}

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.5 - for loops

# %%
# your code here

# %%
fruits = ['apple', 'banana', 'strawberry', 'peach']

# %%
my_dictionary = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964,
    "cities_exhibited": ["Munich", "Boston"]
}

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.6 - Python If ... Else

# %% [markdown]
# <div style='background: lightsalmon; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# A.6 - Functions

# %% [markdown]
# <div style='background: #6A9EB4; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Part 2 - Lab
#
# During today's lab you will write code that will help the College to perform the house lottery more efficiently and assist the house administrations in a variety of tasks.

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Task #1 - automatize the house lottery
#
# In the precirculated template folder, you will find the file students.csv with all rising sophomores that will enter the house lottery, i.e. they will get assigned to one of the twelve undergraduate houses. So far, the college has done this task manually but they hope that you can help them to automtize that process. Please load the csv and add another column 'house_id'. Pyhton's csv package will come in handy to load the csv file and treat each row as a list. Having loaded the file, add a random house id to each student and save that information in a new csv file. You might find the python package 'random' quite useful to automatize the lottery process. We've imported the package for you and provided an example.

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# Examples and precirculated code:

# %%
# house ids lookup tables

house_to_id = {
    'Adams House': 0,
    'Cabot House': 1,
    'Currier House' : 2,
    'Dunster House': 3,
    'Eliot House': 4,
    'Kirkland House': 5,
    'Leverett House': 6,
    'Lowell House': 7,
    'Mather House': 8,
    'Pforzheimer House':9,
    'Quincy House': 10,
    'Winthrop House': 11
}

id_to_house = {
    0: 'Adams House',
    1: 'Cabot House',
    2: 'Currier House',
    3: 'Dunster House',
    4: 'Eliot House',
    5: 'Kirkland House',
    6: 'Leverett House',
    7: 'Lowell House',
    8: 'Mather House',
    9: 'Pforzheimer House',
    10: 'Quincy House',
    11: 'Winthrop House'
}

# %%
# importing useful python packages
import random
import csv

# %%
# some example code snippets how to load a csv file and how to write into one

# read
file_read = open("data/students.csv", "r")
reader = csv.reader(file_read)


for row in reader:
    print(row)
    
file_read.close()

# write - notice that the file doesn't have to exist beforehand! csv write will create the file automatically, which is very useful!
file_write = open('students_with_house.csv', 'w', newline='')

writer = csv.writer(file_write)

# we just write one row here. It might be useful to put this line into a loop when automatizing things
writer.writerow(['first_name', 'last_name', 'HUID','email', 'house_id'])

file_write.close()
# Out:
# ['Oona', 'Swigart', '16076420', 'Oona.Swigart@college.harvard.edu']
# ['Hope', 'Quent', '16435294', 'Hope.Quent@college.harvard.edu']
# ['Fayre', 'Vorster', '11185066', 'Fayre.Vorster@college.harvard.edu']
# ['Priscilla', 'Geffner', '14666772', 'Priscilla.Geffner@college.harvard.edu']
# ['Madeleine', 'Stilwell', '13502774', 'Madeleine.Stilwell@college.harvard.edu']
# ['Deirdre', 'Khorma', '11100518', 'Deirdre.Khorma@college.harvard.edu']
# ['Anthia', 'Blase', '14657089', 'Anthia.Blase@college.harvard.edu']
# ['Diena', 'Shama', '13777228', 'Diena.Shama@college.harvard.edu']
# ['Cristabel', 'Audly', '19191289', 'Cristabel.Audly@college.harvard.edu']
# ['Misha', 'Tybald', '15474105', 'Misha.Tybald@college.harvard.edu']
# ['Carly', 'Haymes', '10825876', 'Carly.Haymes@college.harvard.edu']
# ['Chloris', 'Shaddock', '14456015', 'Chloris.Shaddock@college.harvard.edu']
# ['Evita', 'Whittaker', '16942112', 'Evita.Whittaker@college.harvard.edu']
# ['Fina', 'Zetta', '17941504', 'Fina.Zetta@college.harvard.edu']
# ['Carolina', 'Ummersen', '12399079', 'Carolina.Ummersen@college.harvard.edu']
# ['Roberta', 'Ingra', '11936833', 'Roberta.Ingra@college.harvard.edu']
# ['Moyna', 'Dorothy', '12556187', 'Moyna.Dorothy@college.harvard.edu']
# ['Zondra', 'Cadmar', '12486497', 'Zondra.Cadmar@college.harvard.edu']
# ['Gusty', 'Merat', '11280490', 'Gusty.Merat@college.harvard.edu']
# ['Bertine', 'Merell', '19533403', 'Bertine.Merell@college.harvard.edu']
# ['Pierette', 'Hutchison', '16577108', 'Pierette.Hutchison@college.harvard.edu']
# ['Sue', 'Oneida', '16223298', 'Sue.Oneida@college.harvard.edu']
# ['Gale', 'Hermes', '10553554', 'Gale.Hermes@college.harvard.edu']
# ['Inga', 'Bow', '15657083', 'Inga.Bow@college.harvard.edu']
# ['Jaclyn', 'Flita', '18705071', 'Jaclyn.Flita@college.harvard.edu']
# ['Bernardine', 'Sophronia', '16311101', 'Bernardine.Sophronia@college.harvard.edu']
# ['Chrystel', 'Borrell', '16164885', 'Chrystel.Borrell@college.harvard.edu']
# ['Larine', 'Paton', '14731172', 'Larine.Paton@college.harvard.edu']
# ['Phedra', 'Lia', '11868072', 'Phedra.Lia@college.harvard.edu']
# ['Melanie', 'Merna', '17144995', 'Melanie.Merna@college.harvard.edu']
# ['Emmey', 'Boehike', '19456940', 'Emmey.Boehike@college.harvard.edu']
# ['Alejandra', 'Ehrman', '16185753', 'Alejandra.Ehrman@college.harvard.edu']
# ['Yetty', 'Monaco', '14071918', 'Yetty.Monaco@college.harvard.edu']
# ['Deirdre', 'Ioab', '11777577', 'Deirdre.Ioab@college.harvard.edu']
# ['Catrina', 'Persse', '14686761', 'Catrina.Persse@college.harvard.edu']
# ['Heida', 'Izaak', '13942697', 'Heida.Izaak@college.harvard.edu']
# ['Sharai', 'Meli', '16097823', 'Sharai.Meli@college.harvard.edu']
# ['Aryn', 'Hanleigh', '19408239', 'Aryn.Hanleigh@college.harvard.edu']
# ['Melina', 'Elsinore', '13761016', 'Melina.Elsinore@college.harvard.edu']
# ['Elyssa', 'Wu', '12316153', 'Elyssa.Wu@college.harvard.edu']
# ['Penelopa', 'Harned', '16443115', 'Penelopa.Harned@college.harvard.edu']
# ['Rozele', 'Wilkinson', '15118764', 'Rozele.Wilkinson@college.harvard.edu']
# ['Melina', 'Jethro', '15840321', 'Melina.Jethro@college.harvard.edu']
# ['Jordan', 'Gilmour', '10076614', 'Jordan.Gilmour@college.harvard.edu']
# ['Ethel', 'Hartnett', '11383680', 'Ethel.Hartnett@college.harvard.edu']
# ['Collen', 'Garek', '17585948', 'Collen.Garek@college.harvard.edu']
# ['Jenilee', 'Vastah', '11949445', 'Jenilee.Vastah@college.harvard.edu']
# ['Fredericka', 'Lane', '12958619', 'Fredericka.Lane@college.harvard.edu']
# ['Asia', 'Demitria', '19103295', 'Asia.Demitria@college.harvard.edu']
# ['Ana', 'Scammon', '10701460', 'Ana.Scammon@college.harvard.edu']
# ['Wynne', 'Baylor', '12487005', 'Wynne.Baylor@college.harvard.edu']
# ['Alexine', 'Ackerley', '14493600', 'Alexine.Ackerley@college.harvard.edu']
# ['Fina', 'Himelman', '16919718', 'Fina.Himelman@college.harvard.edu']
# ['Beth', 'Roxanna', '13130130', 'Beth.Roxanna@college.harvard.edu']
# ['Maud', 'Thema', '19209764', 'Maud.Thema@college.harvard.edu']
# ['Myriam', 'Jerold', '11845800', 'Myriam.Jerold@college.harvard.edu']
# ['Kaia', 'Cavan', '19395700', 'Kaia.Cavan@college.harvard.edu']
# ['Mathilda', 'Urania', '19811224', 'Mathilda.Urania@college.harvard.edu']
# ['Merci', 'Louanna', '14261672', 'Merci.Louanna@college.harvard.edu']
# ['Marti', 'Alva', '15373184', 'Marti.Alva@college.harvard.edu']
# ['Keelia', 'Ricki', '11961947', 'Keelia.Ricki@college.harvard.edu']
# ['Lauryn', 'Tamsky', '14140421', 'Lauryn.Tamsky@college.harvard.edu']
# ['Fidelia', 'Cherianne', '14073512', 'Fidelia.Cherianne@college.harvard.edu']
# ['Emylee', 'Emmaline', '17140291', 'Emylee.Emmaline@college.harvard.edu']
# ['Eve', 'Guthrie', '14490284', 'Eve.Guthrie@college.harvard.edu']
# ['Carmencita', 'Drisko', '17368711', 'Carmencita.Drisko@college.harvard.edu']
# ['Nanete', 'Kenwood', '13603325', 'Nanete.Kenwood@college.harvard.edu']
# ['Maridel', 'Madaih', '10107444', 'Maridel.Madaih@college.harvard.edu']
# ['Gerianna', 'Maples', '11245424', 'Gerianna.Maples@college.harvard.edu']
# ['Mariele', 'Sawtelle', '17643066', 'Mariele.Sawtelle@college.harvard.edu']
# ['Winny', 'Markman', '12461674', 'Winny.Markman@college.harvard.edu']
# ['Isa', 'Suanne', '10263083', 'Isa.Suanne@college.harvard.edu']
# ['Barbara', 'Love', '13075253', 'Barbara.Love@college.harvard.edu']
# ['Ronna', 'Loring', '12850713', 'Ronna.Loring@college.harvard.edu']
# ['Jeanna', 'Isidore', '16935372', 'Jeanna.Isidore@college.harvard.edu']
# ['Kary', 'Kamaria', '18903342', 'Kary.Kamaria@college.harvard.edu']
# ['Ann-Marie', 'Sherrie', '13813311', 'Ann-Marie.Sherrie@college.harvard.edu']
# ['Lolita', 'Harday', '18802346', 'Lolita.Harday@college.harvard.edu']
# ['Dorene', 'Jalbert', '17402190', 'Dorene.Jalbert@college.harvard.edu']
# ['Lanae', 'Nore', '12433872', 'Lanae.Nore@college.harvard.edu']
# ['Mureil', 'McLaughlin', '16406290', 'Mureil.McLaughlin@college.harvard.edu']
# ['Barbi', 'Fabiola', '17888309', 'Barbi.Fabiola@college.harvard.edu']
# ['Valera', 'Pandolfi', '15509054', 'Valera.Pandolfi@college.harvard.edu']
# ['Jennica', 'Kiersten', '15651397', 'Jennica.Kiersten@college.harvard.edu']
# ['Cyb', 'Rurik', '10785022', 'Cyb.Rurik@college.harvard.edu']
# ['Celestyna', 'Annice', '16236203', 'Celestyna.Annice@college.harvard.edu']
# ['Robinia', 'Shirberg', '15304763', 'Robinia.Shirberg@college.harvard.edu']
# ['Carol-Jean', 'Elsinore', '13442638', 'Carol-Jean.Elsinore@college.harvard.edu']
# ['Averyl', 'Dorine', '18551575', 'Averyl.Dorine@college.harvard.edu']
# ['Anestassia', 'Hathaway', '19894017', 'Anestassia.Hathaway@college.harvard.edu']
# ['Luci', 'Dulciana', '17658485', 'Luci.Dulciana@college.harvard.edu']
# ['Jenda', 'Diann', '15279072', 'Jenda.Diann@college.harvard.edu']
# ['Patricia', 'Schalles', '11917293', 'Patricia.Schalles@college.harvard.edu']
# ['Bibby', 'Toor', '12441773', 'Bibby.Toor@college.harvard.edu']
# ['Devina', 'Holtz', '14874114', 'Devina.Holtz@college.harvard.edu']
# ['Zia', 'Jillane', '11583059', 'Zia.Jillane@college.harvard.edu']
# ['Gertrud', 'Abbot', '18844206', 'Gertrud.Abbot@college.harvard.edu']
# ['Judy', 'Kiersten', '14471867', 'Judy.Kiersten@college.harvard.edu']
# ['Yolane', 'Thomasina', '13353635', 'Yolane.Thomasina@college.harvard.edu']
# ['Morganica', 'Atcliffe', '18171957', 'Morganica.Atcliffe@college.harvard.edu']
# ['Charlena', 'Nedrud', '17314209', 'Charlena.Nedrud@college.harvard.edu']
# ['Charlena', 'Buffum', '11578825', 'Charlena.Buffum@college.harvard.edu']
# ['Kassey', 'Screens', '16344805', 'Kassey.Screens@college.harvard.edu']
# ['Lizzie', 'Brunell', '11196935', 'Lizzie.Brunell@college.harvard.edu']
# ['Belva', 'Wenoa', '13029453', 'Belva.Wenoa@college.harvard.edu']
# ['Tobe', 'Emmy', '18787384', 'Tobe.Emmy@college.harvard.edu']
# ['Sheree', 'Plato', '16102308', 'Sheree.Plato@college.harvard.edu']
# ['Dania', 'Boycey', '11614816', 'Dania.Boycey@college.harvard.edu']
# ['Chickie', 'Chandler', '17953550', 'Chickie.Chandler@college.harvard.edu']
# ['Sophia', 'Lasley', '14992235', 'Sophia.Lasley@college.harvard.edu']
# ['Joane', 'Bouchard', '15634642', 'Joane.Bouchard@college.harvard.edu']
# ['Ronna', 'Waldron', '17957371', 'Ronna.Waldron@college.harvard.edu']
# ['Merci', 'Ailyn', '14009783', 'Merci.Ailyn@college.harvard.edu']
# ['Fredericka', 'Grimbly', '13591891', 'Fredericka.Grimbly@college.harvard.edu']
# ['Rochette', 'Genna', '19958152', 'Rochette.Genna@college.harvard.edu']
# ['Heddie', 'Newell', '14364128', 'Heddie.Newell@college.harvard.edu']
# ['Dode', 'Clywd', '11331372', 'Dode.Clywd@college.harvard.edu']
# ['Brietta', 'Primalia', '16916977', 'Brietta.Primalia@college.harvard.edu']
# ['Nicoli', 'Morrill', '18458190', 'Nicoli.Morrill@college.harvard.edu']
# ['Misha', 'Cristi', '12765233', 'Misha.Cristi@college.harvard.edu']
# ['Gretal', 'Septima', '14392954', 'Gretal.Septima@college.harvard.edu']
# ['Christy', 'Iiette', '13392284', 'Christy.Iiette@college.harvard.edu']
# ['Nickie', 'Suk', '14479374', 'Nickie.Suk@college.harvard.edu']
# ['Annecorinne', 'Jerald', '14448714', 'Annecorinne.Jerald@college.harvard.edu']
# ['Myriam', 'Sinegold', '15041739', 'Myriam.Sinegold@college.harvard.edu']
# ['Agathe', 'Maribeth', '10512634', 'Agathe.Maribeth@college.harvard.edu']
# ['Renie', 'Cadmar', '10999559', 'Renie.Cadmar@college.harvard.edu']
# ['Eugine', 'Carbo', '13790515', 'Eugine.Carbo@college.harvard.edu']
# ['Tersina', 'Roscoe', '10434851', 'Tersina.Roscoe@college.harvard.edu']
# ['Kayla', 'Roumell', '16667305', 'Kayla.Roumell@college.harvard.edu']
# ['Keelia', 'Tippets', '18861408', 'Keelia.Tippets@college.harvard.edu']
# ['Elsie', 'Quinn', '10763714', 'Elsie.Quinn@college.harvard.edu']
# ['Laurene', 'Daniele', '19854135', 'Laurene.Daniele@college.harvard.edu']
# ['Siana', 'Valoniah', '10971840', 'Siana.Valoniah@college.harvard.edu']
# ['Ardenia', 'Wareing', '11026377', 'Ardenia.Wareing@college.harvard.edu']
# ['Willetta', 'Lay', '10596364', 'Willetta.Lay@college.harvard.edu']
# ['Elfreda', 'Jethro', '16322570', 'Elfreda.Jethro@college.harvard.edu']
# ['Helena', 'Zamora', '12541094', 'Helena.Zamora@college.harvard.edu']
# ['Jessamyn', 'Ahab', '13090028', 'Jessamyn.Ahab@college.harvard.edu']
# ['Marcy', 'Sharl', '11533090', 'Marcy.Sharl@college.harvard.edu']
# ['Kathi', 'Emmy', '13607623', 'Kathi.Emmy@college.harvard.edu']
# ['Jsandye', 'Tamar', '18483554', 'Jsandye.Tamar@college.harvard.edu']
# ['Shandie', 'Wu', '19974709', 'Shandie.Wu@college.harvard.edu']
# ['Daune', 'Lewes', '13258951', 'Daune.Lewes@college.harvard.edu']
# ['Randa', 'Howlyn', '10495975', 'Randa.Howlyn@college.harvard.edu']
# ['Misha', 'Tengdin', '12095147', 'Misha.Tengdin@college.harvard.edu']
# ['Odessa', 'Ricarda', '14005932', 'Odessa.Ricarda@college.harvard.edu']
# ['Olwen', 'Pauly', '12585710', 'Olwen.Pauly@college.harvard.edu']
# ['Ivett', 'Marcellus', '16350342', 'Ivett.Marcellus@college.harvard.edu']
# ['Marti', 'Flyn', '15811996', 'Marti.Flyn@college.harvard.edu']
# ['Kristan', 'Standing', '19728411', 'Kristan.Standing@college.harvard.edu']
# ['Nicoli', 'Rugen', '11798238', 'Nicoli.Rugen@college.harvard.edu']
# ['Tybie', 'Roumell', '19703610', 'Tybie.Roumell@college.harvard.edu']
# ['Natka', 'Zenas', '17293652', 'Natka.Zenas@college.harvard.edu']
# ['Aigneis', 'Zeeba', '15499848', 'Aigneis.Zeeba@college.harvard.edu']
# ['Jasmina', 'Wattenberg', '18112106', 'Jasmina.Wattenberg@college.harvard.edu']
# ['Clarice', 'Kellby', '15104822', 'Clarice.Kellby@college.harvard.edu']
# ['Frances', 'Joni', '10462931', 'Frances.Joni@college.harvard.edu']
# ['Roseline', 'Belanger', '13040203', 'Roseline.Belanger@college.harvard.edu']
# ['Emmey', 'Bryna', '19613038', 'Emmey.Bryna@college.harvard.edu']
# ['Josephine', 'Chaing', '10018430', 'Josephine.Chaing@college.harvard.edu']
# ['Dulcinea', 'Septima', '13505835', 'Dulcinea.Septima@college.harvard.edu']
# ['Hermione', 'Valerio', '12033707', 'Hermione.Valerio@college.harvard.edu']
# ['Glenda', 'Carmena', '16836397', 'Glenda.Carmena@college.harvard.edu']
# ['Lacie', 'Hartnett', '18592300', 'Lacie.Hartnett@college.harvard.edu']
# ['Gilligan', 'Yusuk', '10995865', 'Gilligan.Yusuk@college.harvard.edu']
# ['Raf', 'Sprage', '15721990', 'Raf.Sprage@college.harvard.edu']
# ['Nollie', 'Soneson', '11577153', 'Nollie.Soneson@college.harvard.edu']
# ['Sybille', 'Merriott', '10431764', 'Sybille.Merriott@college.harvard.edu']
# ['Alia', 'Ax', '18292267', 'Alia.Ax@college.harvard.edu']
# ['Linet', 'Rosette', '17390813', 'Linet.Rosette@college.harvard.edu']
# ['Olivette', 'Sprage', '12803689', 'Olivette.Sprage@college.harvard.edu']
# ['Kylynn', 'Garbe', '11890866', 'Kylynn.Garbe@college.harvard.edu']
# ['Sara-Ann', 'Leopold', '14818968', 'Sara-Ann.Leopold@college.harvard.edu']
# ['Orelia', 'Diann', '16575256', 'Orelia.Diann@college.harvard.edu']
# ['Ethel', 'Ariella', '13239167', 'Ethel.Ariella@college.harvard.edu']
# ['Shauna', 'Docilla', '15250156', 'Shauna.Docilla@college.harvard.edu']
# ['Bettine', 'Norrie', '19658917', 'Bettine.Norrie@college.harvard.edu']
# ['Cristabel', 'Shields', '11557985', 'Cristabel.Shields@college.harvard.edu']
# ['Gabi', 'Drisko', '12313850', 'Gabi.Drisko@college.harvard.edu']
# ['Allis', 'Glenden', '18548650', 'Allis.Glenden@college.harvard.edu']
# ['Beatriz', 'Stover', '15517463', 'Beatriz.Stover@college.harvard.edu']
# ['Phedra', 'Daegal', '14322765', 'Phedra.Daegal@college.harvard.edu']
# ['Nerta', 'Maroney', '14711834', 'Nerta.Maroney@college.harvard.edu']
# ['Lorne', 'Schenck', '11660791', 'Lorne.Schenck@college.harvard.edu']
# ['Tressa', 'Roscoe', '18800777', 'Tressa.Roscoe@college.harvard.edu']
# ['Jere', 'Rogerio', '13250942', 'Jere.Rogerio@college.harvard.edu']
# ['Nannie', 'Zetta', '16190963', 'Nannie.Zetta@college.harvard.edu']
# ['Chloris', 'Dyche', '19984627', 'Chloris.Dyche@college.harvard.edu']
# ['Julieta', 'Sheng', '14858247', 'Julieta.Sheng@college.harvard.edu']
# ['Jasmina', 'Ader', '14429841', 'Jasmina.Ader@college.harvard.edu']
# ['Priscilla', 'Vale', '13265824', 'Priscilla.Vale@college.harvard.edu']
# ['Clementine', 'Granoff', '10504852', 'Clementine.Granoff@college.harvard.edu']
# ['Brena', 'Huggins', '11493336', 'Brena.Huggins@college.harvard.edu']
# ['Xylina', 'Yorick', '18703690', 'Xylina.Yorick@college.harvard.edu']
# ['Cordi', 'Bronk', '13062118', 'Cordi.Bronk@college.harvard.edu']
# ['Claudina', 'Artie', '14132861', 'Claudina.Artie@college.harvard.edu']
# ['Laurene', 'Zenas', '16077152', 'Laurene.Zenas@college.harvard.edu']
# ['Raf', 'Alice', '14741315', 'Raf.Alice@college.harvard.edu']
# ['Mady', 'Kunin', '16516136', 'Mady.Kunin@college.harvard.edu']
# ['Priscilla', 'Blisse', '17187246', 'Priscilla.Blisse@college.harvard.edu']
# ['Paola', 'Burnside', '16692120', 'Paola.Burnside@college.harvard.edu']
# ['Genevra', 'Harriman', '17355758', 'Genevra.Harriman@college.harvard.edu']
# ['Nickie', 'Tatianas', '10386375', 'Nickie.Tatianas@college.harvard.edu']
# ['Elvira', 'Thema', '12627778', 'Elvira.Thema@college.harvard.edu']
# ['Blondelle', 'Fink', '12658378', 'Blondelle.Fink@college.harvard.edu']
# ['Janenna', 'Colp', '15106295', 'Janenna.Colp@college.harvard.edu']
# ['Benita', 'Joli', '10084672', 'Benita.Joli@college.harvard.edu']
# ['Teriann', 'Sancho', '15442589', 'Teriann.Sancho@college.harvard.edu']
# ['Giustina', 'Zrike', '10243008', 'Giustina.Zrike@college.harvard.edu']
# ['Dione', 'Rad', '17225979', 'Dione.Rad@college.harvard.edu']
# ['Althea', 'Ingra', '14546027', 'Althea.Ingra@college.harvard.edu']
# ['Rosanne', 'Pierette', '14774090', 'Rosanne.Pierette@college.harvard.edu']
# ['Kaja', 'Mike', '15552390', 'Kaja.Mike@college.harvard.edu']
# ['Siana', 'Annice', '13442797', 'Siana.Annice@college.harvard.edu']
# ['Winny', 'Tryck', '14652923', 'Winny.Tryck@college.harvard.edu']
# ['Sallie', 'Beebe', '12166088', 'Sallie.Beebe@college.harvard.edu']
# ['Alex', 'Clie', '11202302', 'Alex.Clie@college.harvard.edu']
# ['Donnie', 'Mata', '11161830', 'Donnie.Mata@college.harvard.edu']
# ['Marguerite', 'Uird', '10617958', 'Marguerite.Uird@college.harvard.edu']
# ['Tracey', 'Ammann', '17612272', 'Tracey.Ammann@college.harvard.edu']
# ['Vinita', 'Tristram', '17439041', 'Vinita.Tristram@college.harvard.edu']
# ['Gwenneth', 'Pacorro', '16307471', 'Gwenneth.Pacorro@college.harvard.edu']
# ['Cissiee', 'Ehrman', '16000436', 'Cissiee.Ehrman@college.harvard.edu']
# ['Albertina', 'Peg', '16155043', 'Albertina.Peg@college.harvard.edu']
# ['Ayn', 'Tjon', '11108293', 'Ayn.Tjon@college.harvard.edu']
# ['Lila', 'Fink', '12762578', 'Lila.Fink@college.harvard.edu']
# ['Elyssa', 'Ferrell', '14483367', 'Elyssa.Ferrell@college.harvard.edu']
# ['Marjie', 'Tristram', '18960145', 'Marjie.Tristram@college.harvard.edu']
# ['Maisey', 'Gilbertson', '10211491', 'Maisey.Gilbertson@college.harvard.edu']
# ['Lorenza', 'Dearborn', '18290415', 'Lorenza.Dearborn@college.harvard.edu']
# ['Sam', 'Tound', '13871481', 'Sam.Tound@college.harvard.edu']
# ['Jobi', 'Gusella', '15831002', 'Jobi.Gusella@college.harvard.edu']
# ['Sabina', 'Iiette', '14909226', 'Sabina.Iiette@college.harvard.edu']
# ['Fanchon', 'Lewes', '19289772', 'Fanchon.Lewes@college.harvard.edu']
# ['Bettine', 'Niccolo', '12587420', 'Bettine.Niccolo@college.harvard.edu']
# ['Kittie', 'Seumas', '17227745', 'Kittie.Seumas@college.harvard.edu']
# ['Mireielle', 'Ardra', '12726659', 'Mireielle.Ardra@college.harvard.edu']
# ['Chastity', 'Sabella', '13299610', 'Chastity.Sabella@college.harvard.edu']
# ['Averyl', 'Fredi', '10926797', 'Averyl.Fredi@college.harvard.edu']
# ['Tabbatha', 'Nore', '18599543', 'Tabbatha.Nore@college.harvard.edu']
# ['Annecorinne', 'Marijo', '15561593', 'Annecorinne.Marijo@college.harvard.edu']
# ['Brena', 'Kesley', '19274804', 'Brena.Kesley@college.harvard.edu']
# ['Blake', 'Arathorn', '18718806', 'Blake.Arathorn@college.harvard.edu']
# ['Starla', 'Koehler', '12057217', 'Starla.Koehler@college.harvard.edu']
# ['Lila', 'Shanley', '12740931', 'Lila.Shanley@college.harvard.edu']
# ['Lorne', 'Boehike', '11213265', 'Lorne.Boehike@college.harvard.edu']
# ['Adriana', 'McClimans', '16487544', 'Adriana.McClimans@college.harvard.edu']
# ['Charlena', 'Saint', '18206509', 'Charlena.Saint@college.harvard.edu']
# ['Alleen', 'Rosemary', '10161183', 'Alleen.Rosemary@college.harvard.edu']
# ['Fernande', 'Nester', '16794516', 'Fernande.Nester@college.harvard.edu']
# ['Nelle', 'Cassius', '12046452', 'Nelle.Cassius@college.harvard.edu']
# ['Keelia', 'Chinua', '16704646', 'Keelia.Chinua@college.harvard.edu']
# ['Brietta', 'Bartlett', '11396882', 'Brietta.Bartlett@college.harvard.edu']
# ['Viki', 'Dahlia', '14758454', 'Viki.Dahlia@college.harvard.edu']
# ['Bertine', 'Newell', '19032590', 'Bertine.Newell@college.harvard.edu']
# ['Rozele', 'Cleavland', '15945516', 'Rozele.Cleavland@college.harvard.edu']
# ['Beth', 'Kress', '15596629', 'Beth.Kress@college.harvard.edu']
# ['Neila', 'Haymes', '16440834', 'Neila.Haymes@college.harvard.edu']
# ['Dotty', 'Dex', '16624239', 'Dotty.Dex@college.harvard.edu']
# ['Cindelyn', 'Joni', '16161089', 'Cindelyn.Joni@college.harvard.edu']
# ['Doro', 'Dom', '17592122', 'Doro.Dom@college.harvard.edu']
# ['Bibby', 'Halsey', '19785346', 'Bibby.Halsey@college.harvard.edu']
# ['Jacenta', 'Lory', '14648651', 'Jacenta.Lory@college.harvard.edu']
# ['Kylynn', 'Warthman', '13782079', 'Kylynn.Warthman@college.harvard.edu']
# ['Ruthe', 'Dannye', '17566782', 'Ruthe.Dannye@college.harvard.edu']
# ['Estell', 'Swanhildas', '15322491', 'Estell.Swanhildas@college.harvard.edu']
# ['Jaclyn', 'Ioab', '12898682', 'Jaclyn.Ioab@college.harvard.edu']
# ['Rosene', 'Artie', '14866879', 'Rosene.Artie@college.harvard.edu']
# ['Ekaterina', 'Salvidor', '15037295', 'Ekaterina.Salvidor@college.harvard.edu']
# ['Deedee', 'Stanwood', '17175615', 'Deedee.Stanwood@college.harvard.edu']
# ['Rivalee', 'Willie', '15107055', 'Rivalee.Willie@college.harvard.edu']
# ['Atlanta', 'Elbertina', '19463693', 'Atlanta.Elbertina@college.harvard.edu']
# ['Jerry', 'Adamsen', '13635100', 'Jerry.Adamsen@college.harvard.edu']
# ['Constance', 'Gilbertson', '19270895', 'Constance.Gilbertson@college.harvard.edu']
# ['Agathe', 'Zachary', '10057785', 'Agathe.Zachary@college.harvard.edu']
# ['Ottilie', 'Pond', '19601509', 'Ottilie.Pond@college.harvard.edu']
# ['Korrie', 'Berl', '16614900', 'Korrie.Berl@college.harvard.edu']
# ['Bibby', 'Lissi', '16096602', 'Bibby.Lissi@college.harvard.edu']
# ['Ellette', 'Ellord', '17926648', 'Ellette.Ellord@college.harvard.edu']
# ['Dorene', 'Casimir', '14420637', 'Dorene.Casimir@college.harvard.edu']
# ['Vevay', 'Sancho', '15364919', 'Vevay.Sancho@college.harvard.edu']
# ['Raina', 'Kristi', '19694978', 'Raina.Kristi@college.harvard.edu']
# ['Justinn', 'Mallon', '18157448', 'Justinn.Mallon@college.harvard.edu']
# ['Raquela', 'Lenny', '18924933', 'Raquela.Lenny@college.harvard.edu']
# ['Rosanne', 'Graig', '13501056', 'Rosanne.Graig@college.harvard.edu']
# ['Devina', 'Fontana', '15837609', 'Devina.Fontana@college.harvard.edu']
# ['Ann-Marie', 'Eldrid', '17484776', 'Ann-Marie.Eldrid@college.harvard.edu']
# ['Jeanna', 'Velick', '10123917', 'Jeanna.Velick@college.harvard.edu']
# ['Keelia', 'Cordi', '19066481', 'Keelia.Cordi@college.harvard.edu']
# ['Merle', 'Ioab', '19055556', 'Merle.Ioab@college.harvard.edu']
# ['Corly', 'Stelle', '13629300', 'Corly.Stelle@college.harvard.edu']
# ['Hannis', 'Arquit', '11659272', 'Hannis.Arquit@college.harvard.edu']
# ['Jan', 'Killigrew', '12211147', 'Jan.Killigrew@college.harvard.edu']
# ['Amalie', 'Jena', '15711842', 'Amalie.Jena@college.harvard.edu']
# ['Michaelina', 'Decato', '16556965', 'Michaelina.Decato@college.harvard.edu']
# ['Belinda', 'Iiette', '13087109', 'Belinda.Iiette@college.harvard.edu']
# ['Cissiee', 'Emmy', '12260660', 'Cissiee.Emmy@college.harvard.edu']
# ['Ezmeralda', 'Lindemann', '19575575', 'Ezmeralda.Lindemann@college.harvard.edu']
# ['Bobinette', 'Matthew', '15380655', 'Bobinette.Matthew@college.harvard.edu']
# ['Alia', 'Wenoa', '13934131', 'Alia.Wenoa@college.harvard.edu']
# ['Leia', 'Nance', '17649524', 'Leia.Nance@college.harvard.edu']
# ['Roberta', 'Truc', '10732636', 'Roberta.Truc@college.harvard.edu']
# ['Carol-Jean', 'Eno', '15376129', 'Carol-Jean.Eno@college.harvard.edu']
# ['Averyl', 'Brieta', '15653824', 'Averyl.Brieta@college.harvard.edu']
# ['Dale', 'Podvin', '15623256', 'Dale.Podvin@college.harvard.edu']
# ['Frieda', "O'Rourke", '17981599', "Frieda.O'Rourke@college.harvard.edu"]
# ['Linzy', 'Maribeth', '18033621', 'Linzy.Maribeth@college.harvard.edu']
# ['Laure', 'Aloise', '13243090', 'Laure.Aloise@college.harvard.edu']
# ['Evaleen', 'Wolfgram', '13940303', 'Evaleen.Wolfgram@college.harvard.edu']
# ['Nariko', 'Sallyann', '18953266', 'Nariko.Sallyann@college.harvard.edu']
# ['Aurelie', 'Ortrude', '10158974', 'Aurelie.Ortrude@college.harvard.edu']
# ['Minne', 'Thornburg', '10037617', 'Minne.Thornburg@college.harvard.edu']
# ['Silvana', 'McClimans', '11514978', 'Silvana.McClimans@college.harvard.edu']
# ['Tori', 'Emmaline', '14764368', 'Tori.Emmaline@college.harvard.edu']
# ['Reeba', 'Wyn', '18793626', 'Reeba.Wyn@college.harvard.edu']
# ['Brandise', 'Delila', '11340377', 'Brandise.Delila@college.harvard.edu']
# ['Siana', 'Soneson', '17998677', 'Siana.Soneson@college.harvard.edu']
# ['Fredericka', 'Emanuel', '16334739', 'Fredericka.Emanuel@college.harvard.edu']
# ['Valeda', 'Fiester', '14512673', 'Valeda.Fiester@college.harvard.edu']
# ['Rosabelle', 'Lymann', '12009571', 'Rosabelle.Lymann@college.harvard.edu']
# ['Xylina', 'Guildroy', '16246904', 'Xylina.Guildroy@college.harvard.edu']
# ['Mady', 'Larochelle', '14035179', 'Mady.Larochelle@college.harvard.edu']
# ['Selia', 'Llovera', '14302923', 'Selia.Llovera@college.harvard.edu']
# ['Joelly', "O'Carroll", '14035190', "Joelly.O'Carroll@college.harvard.edu"]
# ['Alex', 'Modie', '12824975', 'Alex.Modie@college.harvard.edu']
# ['Betta', 'Zachary', '10062689', 'Betta.Zachary@college.harvard.edu']
# ['Josephine', 'Wesle', '11985936', 'Josephine.Wesle@college.harvard.edu']
# ['Aeriela', 'Maribeth', '16336632', 'Aeriela.Maribeth@college.harvard.edu']
# ['Ivett', 'Rona', '19991106', 'Ivett.Rona@college.harvard.edu']
# ['Clary', 'Stevy', '14691987', 'Clary.Stevy@college.harvard.edu']
# ['Zondra', 'Kathie', '19999567', 'Zondra.Kathie@college.harvard.edu']
# ['Susette', 'Elephus', '15826857', 'Susette.Elephus@college.harvard.edu']
# ['Britte', 'Yate', '12685480', 'Britte.Yate@college.harvard.edu']
# ['Edyth', 'Concha', '19745556', 'Edyth.Concha@college.harvard.edu']
# ['Thalia', 'Atonsah', '13035523', 'Thalia.Atonsah@college.harvard.edu']
# ['Marti', 'Slifka', '12227793', 'Marti.Slifka@college.harvard.edu']
# ['Gilda', 'Gillan', '14094779', 'Gilda.Gillan@college.harvard.edu']
# ['Lyssa', 'Timon', '19679574', 'Lyssa.Timon@college.harvard.edu']
# ['Vonny', 'Behre', '10551097', 'Vonny.Behre@college.harvard.edu']
# ['Nollie', 'Clie', '12582290', 'Nollie.Clie@college.harvard.edu']
# ['Rubie', 'Allare', '17495367', 'Rubie.Allare@college.harvard.edu']
# ['Kamilah', 'Margret', '14691040', 'Kamilah.Margret@college.harvard.edu']
# ['Audrie', 'Weaks', '11069346', 'Audrie.Weaks@college.harvard.edu']
# ['Latisha', 'Fink', '18665119', 'Latisha.Fink@college.harvard.edu']
# ['Belva', 'Hylan', '15664126', 'Belva.Hylan@college.harvard.edu']
# ['Kary', 'Valerio', '17362838', 'Kary.Valerio@college.harvard.edu']
# ['Fayre', 'Dawkins', '12600497', 'Fayre.Dawkins@college.harvard.edu']
# ['Katleen', 'Norvol', '16415829', 'Katleen.Norvol@college.harvard.edu']
# ['Angela', 'Harned', '16145536', 'Angela.Harned@college.harvard.edu']
# ['Lanae', 'Arley', '18467116', 'Lanae.Arley@college.harvard.edu']
# ['Marline', 'Himelman', '18829950', 'Marline.Himelman@college.harvard.edu']
# ['Jessamyn', 'Konyn', '11424171', 'Jessamyn.Konyn@college.harvard.edu']
# ['Shell', 'Elvyn', '18673040', 'Shell.Elvyn@college.harvard.edu']
# ['Fred', 'Stuart', '16955982', 'Fred.Stuart@college.harvard.edu']
# ['Lesly', 'Serilda', '14253166', 'Lesly.Serilda@college.harvard.edu']
# ['Violet', 'Pearse', '16987852', 'Violet.Pearse@college.harvard.edu']
# ['Marline', 'Myrilla', '15466072', 'Marline.Myrilla@college.harvard.edu']
# ['Evita', 'Vary', '14410079', 'Evita.Vary@college.harvard.edu']
# ['Sashenka', 'Dudley', '19374537', 'Sashenka.Dudley@college.harvard.edu']
# ['Anallese', 'Goth', '17927182', 'Anallese.Goth@college.harvard.edu']
# ['Louella', 'Eachern', '11791568', 'Louella.Eachern@college.harvard.edu']
# ['Hildegaard', 'Dearborn', '16787469', 'Hildegaard.Dearborn@college.harvard.edu']
# ['Amalie', 'Alabaster', '16930954', 'Amalie.Alabaster@college.harvard.edu']
# ['Dale', 'Ries', '15313867', 'Dale.Ries@college.harvard.edu']
# ['Briney', 'Hoban', '17562479', 'Briney.Hoban@college.harvard.edu']
# ['Deane', 'Malvino', '15124670', 'Deane.Malvino@college.harvard.edu']
# ['Karlee', 'Freddi', '12962460', 'Karlee.Freddi@college.harvard.edu']
# ['Reeba', 'Anyah', '13425993', 'Reeba.Anyah@college.harvard.edu']
# ['Netty', 'Jagir', '17321044', 'Netty.Jagir@college.harvard.edu']
# ['Sissy', 'Nerita', '11476996', 'Sissy.Nerita@college.harvard.edu']
# ['Iseabal', 'Bashemeth', '17926064', 'Iseabal.Bashemeth@college.harvard.edu']
# ['Tracey', 'Hartnett', '12769868', 'Tracey.Hartnett@college.harvard.edu']
# ['Myriam', 'Fabiola', '13646566', 'Myriam.Fabiola@college.harvard.edu']
# ['Zsa Zsa', 'Lynn', '17628953', 'Zsa Zsa.Lynn@college.harvard.edu']
# ['Loree', 'Damarra', '17314349', 'Loree.Damarra@college.harvard.edu']
# ['Ardys', 'Ursulette', '19257991', 'Ardys.Ursulette@college.harvard.edu']
# ['Aimil', 'Reneta', '11416674', 'Aimil.Reneta@college.harvard.edu']
# ['Antonietta', 'Wenoa', '14303360', 'Antonietta.Wenoa@college.harvard.edu']
# ['Shauna', 'Jillane', '19604214', 'Shauna.Jillane@college.harvard.edu']
# ['Nyssa', 'Lorain', '11661745', 'Nyssa.Lorain@college.harvard.edu']
# ['Anica', 'Yusuk', '17348593', 'Anica.Yusuk@college.harvard.edu']
# ['Rosabelle', 'Haerr', '14713897', 'Rosabelle.Haerr@college.harvard.edu']
# ['Zaria', 'Hollingsworth', '18200710', 'Zaria.Hollingsworth@college.harvard.edu']
# ['Betta', 'Cullin', '14207386', 'Betta.Cullin@college.harvard.edu']
# ['Rhoda', 'Mathilde', '11529282', 'Rhoda.Mathilde@college.harvard.edu']
# ['Camile', 'Noelyn', '15734485', 'Camile.Noelyn@college.harvard.edu']
# ['Claudina', 'Eben', '15516426', 'Claudina.Eben@college.harvard.edu']
# ['Caryl', 'Gabrielli', '11664492', 'Caryl.Gabrielli@college.harvard.edu']
# ['Jinny', 'Haerr', '14135401', 'Jinny.Haerr@college.harvard.edu']
# ['Riannon', 'Redmond', '19596885', 'Riannon.Redmond@college.harvard.edu']
# ['Vere', 'Mitzi', '15866728', 'Vere.Mitzi@college.harvard.edu']
# ['Lynnea', 'Daveta', '15787314', 'Lynnea.Daveta@college.harvard.edu']
# ['Binny', 'Medrek', '17630510', 'Binny.Medrek@college.harvard.edu']
# ['Claresta', 'Chrystel', '18203756', 'Claresta.Chrystel@college.harvard.edu']
# ['Jessy', 'Justinn', '15859306', 'Jessy.Justinn@college.harvard.edu']
# ['Raina', 'Jammal', '13224952', 'Raina.Jammal@college.harvard.edu']
# ['Lolita', 'Therine', '11513216', 'Lolita.Therine@college.harvard.edu']
# ['Aigneis', 'Craggie', '12628083', 'Aigneis.Craggie@college.harvard.edu']
# ['Renie', 'Heisel', '15944090', 'Renie.Heisel@college.harvard.edu']
# ['Magdalena', 'Yate', '16477699', 'Magdalena.Yate@college.harvard.edu']
# ['Dacia', 'Harriman', '13555102', 'Dacia.Harriman@college.harvard.edu']
# ['Josephine', 'Grosz', '10004157', 'Josephine.Grosz@college.harvard.edu']
# ['Aaren', 'Timon', '18630067', 'Aaren.Timon@college.harvard.edu']
# ['Jennica', 'Pettiford', '11417817', 'Jennica.Pettiford@college.harvard.edu']
# ['Cristabel', 'Cadmar', '14805294', 'Cristabel.Cadmar@college.harvard.edu']
# ['Claresta', 'Nahum', '10315953', 'Claresta.Nahum@college.harvard.edu']
# ['Doralynne', 'Baylor', '14077800', 'Doralynne.Baylor@college.harvard.edu']
# ['Brietta', 'Morgun', '17641524', 'Brietta.Morgun@college.harvard.edu']
# ['Ardenia', 'Chobot', '14627170', 'Ardenia.Chobot@college.harvard.edu']
# ['Tarra', 'Emmy', '19126333', 'Tarra.Emmy@college.harvard.edu']
# ['Ileana', 'Michella', '14244904', 'Ileana.Michella@college.harvard.edu']
# ['Julieta', 'Dash', '12116605', 'Julieta.Dash@college.harvard.edu']
# ['Beverley', 'Wooster', '12413095', 'Beverley.Wooster@college.harvard.edu']
# ['Luci', 'Corabella', '17742824', 'Luci.Corabella@college.harvard.edu']
# ['Lila', 'Bergman', '18979745', 'Lila.Bergman@college.harvard.edu']
# ['Patricia', 'Alejoa', '16214403', 'Patricia.Alejoa@college.harvard.edu']
# ['Mathilda', 'Mauer', '19854714', 'Mathilda.Mauer@college.harvard.edu']
# ['Ottilie', 'Codding', '12467150', 'Ottilie.Codding@college.harvard.edu']
# ['Teddie', 'Anestassia', '13867822', 'Teddie.Anestassia@college.harvard.edu']
# ['Berta', 'Ade', '13418125', 'Berta.Ade@college.harvard.edu']
# ['Teriann', 'Dorcy', '17891433', 'Teriann.Dorcy@college.harvard.edu']
# ['Nananne', "O'Carroll", '15923124', "Nananne.O'Carroll@college.harvard.edu"]
# ['Brynna', 'Lunsford', '11392410', 'Brynna.Lunsford@college.harvard.edu']
# ['Ida', 'Shuler', '19521623', 'Ida.Shuler@college.harvard.edu']
# ['Aimil', 'Tacye', '15221282', 'Aimil.Tacye@college.harvard.edu']
# ['Monika', 'Allare', '16411504', 'Monika.Allare@college.harvard.edu']
# ['Roxane', 'Pitt', '18385898', 'Roxane.Pitt@college.harvard.edu']
# ['Elbertina', 'Chesna', '13813191', 'Elbertina.Chesna@college.harvard.edu']
# ['Malina', 'Hessler', '19374064', 'Malina.Hessler@college.harvard.edu']
# ['Eolanda', 'Elvyn', '14220399', 'Eolanda.Elvyn@college.harvard.edu']
# ['Adore', 'Cynar', '13732698', 'Adore.Cynar@college.harvard.edu']
# ['Dale', 'Blake', '19847603', 'Dale.Blake@college.harvard.edu']
# ['Cam', 'Rodmann', '14523012', 'Cam.Rodmann@college.harvard.edu']
# ['Roz', 'Magnolia', '13477994', 'Roz.Magnolia@college.harvard.edu']
# ['Beatriz', 'Clara', '15921985', 'Beatriz.Clara@college.harvard.edu']
# ['Caressa', 'Granoff', '10940599', 'Caressa.Granoff@college.harvard.edu']
# ['Codie', 'Gregrory', '15673708', 'Codie.Gregrory@college.harvard.edu']
# ['Mathilda', 'Cosenza', '13908008', 'Mathilda.Cosenza@college.harvard.edu']
# ['Bobinette', 'Jagir', '17701556', 'Bobinette.Jagir@college.harvard.edu']
# ['Lacie', 'Velick', '16440009', 'Lacie.Velick@college.harvard.edu']
# ['Carly', 'Hebner', '11834210', 'Carly.Hebner@college.harvard.edu']
# ['Molli', 'Belldas', '17872710', 'Molli.Belldas@college.harvard.edu']
# ['Edith', 'Niles', '14699985', 'Edith.Niles@college.harvard.edu']
# ['Yetty', 'Ralfston', '17852222', 'Yetty.Ralfston@college.harvard.edu']
# ['Briney', 'Means', '19899421', 'Briney.Means@college.harvard.edu']
# ['Ida', 'Linehan', '18798588', 'Ida.Linehan@college.harvard.edu']
# ['Gwyneth', 'Juliet', '13474778', 'Gwyneth.Juliet@college.harvard.edu']
# ['Joleen', 'Madelene', '18827190', 'Joleen.Madelene@college.harvard.edu']
# ['Lory', 'Kat', '11308726', 'Lory.Kat@college.harvard.edu']
# ['Wilma', 'Kamaria', '14830012', 'Wilma.Kamaria@college.harvard.edu']
# ['Gloria', 'Amadas', '12220298', 'Gloria.Amadas@college.harvard.edu']
# ['Krystle', 'Vins', '16731455', 'Krystle.Vins@college.harvard.edu']
# ['Jessy', 'Rodmann', '11879077', 'Jessy.Rodmann@college.harvard.edu']
# ['Winny', 'Gerge', '16197304', 'Winny.Gerge@college.harvard.edu']
# ['Aimil', 'Constancy', '10888866', 'Aimil.Constancy@college.harvard.edu']
# ['Chere', 'Neva', '10493179', 'Chere.Neva@college.harvard.edu']
# ['Beatriz', 'Helve', '10348066', 'Beatriz.Helve@college.harvard.edu']
# ['Hannis', 'Huggins', '18598141', 'Hannis.Huggins@college.harvard.edu']
# ['Edyth', 'Nisbet', '10370788', 'Edyth.Nisbet@college.harvard.edu']
# ['Mahalia', 'Hilbert', '15163827', 'Mahalia.Hilbert@college.harvard.edu']
# ['Carmencita', 'Mullane', '10923218', 'Carmencita.Mullane@college.harvard.edu']
# ['Blake', 'Fredi', '12897689', 'Blake.Fredi@college.harvard.edu']
# ['Malina', 'Seligman', '10541114', 'Malina.Seligman@college.harvard.edu']
# ['Annora', 'Riva', '16776558', 'Annora.Riva@college.harvard.edu']
# ['Rubie', 'Sandye', '18111496', 'Rubie.Sandye@college.harvard.edu']
# ['Adelle', 'Wandie', '17206590', 'Adelle.Wandie@college.harvard.edu']
# ['Sue', 'Arley', '14858721', 'Sue.Arley@college.harvard.edu']
# ['Melisent', 'Xerxes', '15057567', 'Melisent.Xerxes@college.harvard.edu']
# ['Romona', 'Gilbertson', '19250888', 'Romona.Gilbertson@college.harvard.edu']
# ['Modestia', 'Center', '12591112', 'Modestia.Center@college.harvard.edu']
# ['Berget', 'Charity', '14398281', 'Berget.Charity@college.harvard.edu']
# ['Susette', 'Kiersten', '14398052', 'Susette.Kiersten@college.harvard.edu']
# ['Millie', 'Johanna', '14217321', 'Millie.Johanna@college.harvard.edu']
# ['Lacie', 'Phyllis', '18497809', 'Lacie.Phyllis@college.harvard.edu']
# ['Gerrie', 'Taam', '12137298', 'Gerrie.Taam@college.harvard.edu']
# ['Riannon', 'Raseda', '13800219', 'Riannon.Raseda@college.harvard.edu']
# ['Farrah', 'Persse', '15121382', 'Farrah.Persse@college.harvard.edu']
# ['Cordi', 'Nester', '15385272', 'Cordi.Nester@college.harvard.edu']
# ['Henriette', 'Manolo', '10578825', 'Henriette.Manolo@college.harvard.edu']
# ['Almeta', 'Erich', '15984018', 'Almeta.Erich@college.harvard.edu']
# ['Heddie', 'Drus', '14151283', 'Heddie.Drus@college.harvard.edu']
# ['Wynne', 'Orpah', '18984001', 'Wynne.Orpah@college.harvard.edu']
# ['Marjie', 'Johanna', '16153602', 'Marjie.Johanna@college.harvard.edu']
# ['Miquela', 'Koziara', '17633129', 'Miquela.Koziara@college.harvard.edu']
# ['Deedee', 'Dunkin', '10220203', 'Deedee.Dunkin@college.harvard.edu']
# ['Halette', 'Smitt', '16408364', 'Halette.Smitt@college.harvard.edu']
# ['Valli', 'Cath', '18748627', 'Valli.Cath@college.harvard.edu']
# ['Modestia', 'Hollingsworth', '10118286', 'Modestia.Hollingsworth@college.harvard.edu']
# ['Genevra', 'Pulsifer', '18354386', 'Genevra.Pulsifer@college.harvard.edu']
# ['Cyndie', 'Flita', '14725651', 'Cyndie.Flita@college.harvard.edu']
# ['Sara-Ann', 'Kirbee', '16507157', 'Sara-Ann.Kirbee@college.harvard.edu']
# ['Oona', 'Flita', '11679528', 'Oona.Flita@college.harvard.edu']
# ['Sadie', 'Guildroy', '13973494', 'Sadie.Guildroy@college.harvard.edu']
# ['Susan', 'Grosz', '19302731', 'Susan.Grosz@college.harvard.edu']
# ['Georgina', 'Norrie', '16152376', 'Georgina.Norrie@college.harvard.edu']
# ['Cam', 'Roumell', '16349829', 'Cam.Roumell@college.harvard.edu']
# ['Consuela', 'Haerr', '13072923', 'Consuela.Haerr@college.harvard.edu']
# ['Rori', 'Hebner', '19289418', 'Rori.Hebner@college.harvard.edu']
# ['Georgetta', 'Linehan', '15549268', 'Georgetta.Linehan@college.harvard.edu']
# ['Tracey', 'Kenney', '12275100', 'Tracey.Kenney@college.harvard.edu']
# ['Elfreda', 'Roarke', '17265644', 'Elfreda.Roarke@college.harvard.edu']
# ['Linet', 'Brian', '13502166', 'Linet.Brian@college.harvard.edu']
# ['Melisent', 'Daveta', '12394314', 'Melisent.Daveta@college.harvard.edu']
# ['Demetris', 'Janene', '15971480', 'Demetris.Janene@college.harvard.edu']
# ['Therine', 'Durante', '11377390', 'Therine.Durante@college.harvard.edu']
# ['Lolita', 'Esmaria', '10966939', 'Lolita.Esmaria@college.harvard.edu']
# ['Harmonia', 'Mike', '18002861', 'Harmonia.Mike@college.harvard.edu']
# ['Mallory', 'Bandeen', '16165052', 'Mallory.Bandeen@college.harvard.edu']
# ['Alameda', 'Pozzy', '11272947', 'Alameda.Pozzy@college.harvard.edu']
# ['Wanda', 'Primalia', '10595043', 'Wanda.Primalia@college.harvard.edu']
# ['Jany', 'Yuille', '14300562', 'Jany.Yuille@college.harvard.edu']
# ['Shandie', 'Kaete', '12267475', 'Shandie.Kaete@college.harvard.edu']
# ['Shandie', 'Kronfeld', '16293724', 'Shandie.Kronfeld@college.harvard.edu']
# ['Adriana', 'Joni', '13722087', 'Adriana.Joni@college.harvard.edu']
# ['Jany', 'Chick', '16714167', 'Jany.Chick@college.harvard.edu']
# ['Shaylyn', 'Dermott', '15790783', 'Shaylyn.Dermott@college.harvard.edu']
# ['Nannie', 'Kamaria', '12036948', 'Nannie.Kamaria@college.harvard.edu']
# ['Hyacinthe', 'Ardeha', '10077366', 'Hyacinthe.Ardeha@college.harvard.edu']
# ['Rhea', 'Honoria', '14749518', 'Rhea.Honoria@college.harvard.edu']
# ['Bertine', 'Viddah', '15471520', 'Bertine.Viddah@college.harvard.edu']
# ['Tersina', 'Maisey', '18234618', 'Tersina.Maisey@college.harvard.edu']
# ['Farrah', 'Kronfeld', '13465275', 'Farrah.Kronfeld@college.harvard.edu']
# ['Mady', 'Ferrell', '13518774', 'Mady.Ferrell@college.harvard.edu']
# ['Tracey', 'Bennie', '15049751', 'Tracey.Bennie@college.harvard.edu']
# ['Atlanta', 'Mauer', '12565564', 'Atlanta.Mauer@college.harvard.edu']
# ['Ricky', 'Beebe', '10279094', 'Ricky.Beebe@college.harvard.edu']
# ['Minne', 'Melan', '18978146', 'Minne.Melan@college.harvard.edu']
# ['Kayla', 'Kaete', '11745772', 'Kayla.Kaete@college.harvard.edu']
# ['Ashlee', 'Rurik', '15452212', 'Ashlee.Rurik@college.harvard.edu']
# ['Vanessa', 'Ardra', '15201110', 'Vanessa.Ardra@college.harvard.edu']
# ['Shauna', 'Nedrud', '17787736', 'Shauna.Nedrud@college.harvard.edu']
# ['Merry', 'Meli', '19293136', 'Merry.Meli@college.harvard.edu']
# ['Vanessa', 'Baptlsta', '17907239', 'Vanessa.Baptlsta@college.harvard.edu']
# ['Brana', 'Tacye', '19181978', 'Brana.Tacye@college.harvard.edu']
# ['Esmeralda', 'Nikaniki', '16722854', 'Esmeralda.Nikaniki@college.harvard.edu']
# ['Ann-Marie', 'Sherfield', '12584791', 'Ann-Marie.Sherfield@college.harvard.edu']
# ['Mara', 'Alva', '19709563', 'Mara.Alva@college.harvard.edu']
# ['Johna', 'Gunn', '14787982', 'Johna.Gunn@college.harvard.edu']
# ['Charlena', 'Redmond', '10221543', 'Charlena.Redmond@college.harvard.edu']
# ['Jerry', 'Naor', '11001071', 'Jerry.Naor@college.harvard.edu']
# ['Tarra', 'Hessler', '14325727', 'Tarra.Hessler@college.harvard.edu']
# ['Karina', 'Demitria', '13558041', 'Karina.Demitria@college.harvard.edu']
# ['Laure', 'Shama', '16817632', 'Laure.Shama@college.harvard.edu']
# ['Emylee', 'Felecia', '19931607', 'Emylee.Felecia@college.harvard.edu']
# ['Allyce', 'Melony', '14607204', 'Allyce.Melony@college.harvard.edu']
# ['Chloris', 'Seumas', '15887530', 'Chloris.Seumas@college.harvard.edu']
# ['Dede', 'Reinke', '16737716', 'Dede.Reinke@college.harvard.edu']
# ['Harmonia', 'Diogenes', '14499510', 'Harmonia.Diogenes@college.harvard.edu']
# ['Benita', 'Zola', '18055753', 'Benita.Zola@college.harvard.edu']
# ['Florencia', 'Marlie', '11345702', 'Florencia.Marlie@college.harvard.edu']
# ['Darlleen', 'Reidar', '19734836', 'Darlleen.Reidar@college.harvard.edu']
# ['Aeriela', 'Lanita', '12740103', 'Aeriela.Lanita@college.harvard.edu']
# ['Lita', 'Jalbert', '16737782', 'Lita.Jalbert@college.harvard.edu']
# ['Esmeralda', 'Swanhildas', '18090887', 'Esmeralda.Swanhildas@college.harvard.edu']
# ['Vivia', 'Marden', '17397965', 'Vivia.Marden@college.harvard.edu']
# ['Lorenza', 'Koehler', '18869543', 'Lorenza.Koehler@college.harvard.edu']
# ['Valli', 'Lattie', '16073877', 'Valli.Lattie@college.harvard.edu']
# ['Renie', 'Pettiford', '11890478', 'Renie.Pettiford@college.harvard.edu']
# ['Flory', 'Raama', '12275983', 'Flory.Raama@college.harvard.edu']
# ['Vanessa', 'Ogren', '10174272', 'Vanessa.Ogren@college.harvard.edu']
# ['Shaine', 'Meli', '15484522', 'Shaine.Meli@college.harvard.edu']
# ['Ilse', 'Zetta', '13378562', 'Ilse.Zetta@college.harvard.edu']
# ['Kathi', 'Urania', '12496538', 'Kathi.Urania@college.harvard.edu']
# ['Aigneis', 'Bartlett', '18616245', 'Aigneis.Bartlett@college.harvard.edu']
# ['Dede', 'Vanni', '11772048', 'Dede.Vanni@college.harvard.edu']
# ['Karina', 'Septima', '10705116', 'Karina.Septima@college.harvard.edu']
# ['Lenna', 'Gillan', '16279900', 'Lenna.Gillan@college.harvard.edu']
# ['Tatiania', 'Jacobah', '11556886', 'Tatiania.Jacobah@college.harvard.edu']
# ['Kimmy', 'Erb', '16700176', 'Kimmy.Erb@college.harvard.edu']
# ['Allyce', 'Kathie', '17267839', 'Allyce.Kathie@college.harvard.edu']
# ['Dorice', 'Emmaline', '10494020', 'Dorice.Emmaline@college.harvard.edu']
# ['Latisha', 'Aaberg', '14259647', 'Latisha.Aaberg@college.harvard.edu']
# ['Odessa', 'Fredi', '18714567', 'Odessa.Fredi@college.harvard.edu']
# ['Tamqrah', 'Melan', '13452539', 'Tamqrah.Melan@college.harvard.edu']
# ['Nelle', 'Behre', '16448122', 'Nelle.Behre@college.harvard.edu']
# ['Daphne', 'Eliathas', '13658434', 'Daphne.Eliathas@college.harvard.edu']
# ['Sharlene', 'Carolin', '12191886', 'Sharlene.Carolin@college.harvard.edu']
# ['Kaja', 'Carbo', '10160444', 'Kaja.Carbo@college.harvard.edu']
# ['Agathe', 'Janith', '15193473', 'Agathe.Janith@college.harvard.edu']
# ['Jennica', 'Carleen', '14124106', 'Jennica.Carleen@college.harvard.edu']
# ['Lolita', 'Rheingold', '12345849', 'Lolita.Rheingold@college.harvard.edu']
# ['Xylina', 'Even', '13230029', 'Xylina.Even@college.harvard.edu']
# ['Corina', 'Khorma', '18801221', 'Corina.Khorma@college.harvard.edu']
# ['Lucille', 'Jalbert', '17029227', 'Lucille.Jalbert@college.harvard.edu']
# ['Desirae', 'Schenck', '10687802', 'Desirae.Schenck@college.harvard.edu']
# ['Clarice', 'Constancy', '18401177', 'Clarice.Constancy@college.harvard.edu']
# ['Kalina', 'Byrne', '16172206', 'Kalina.Byrne@college.harvard.edu']
# ['Ottilie', 'Jarib', '13711019', 'Ottilie.Jarib@college.harvard.edu']
# ['Millie', 'Tound', '10802903', 'Millie.Tound@college.harvard.edu']
# ['Molli', 'Orpah', '15713449', 'Molli.Orpah@college.harvard.edu']
# ['Aeriela', 'Tannie', '13806999', 'Aeriela.Tannie@college.harvard.edu']
# ['Meg', 'Alice', '16445431', 'Meg.Alice@college.harvard.edu']
# ['Elka', 'Sikorski', '17302491', 'Elka.Sikorski@college.harvard.edu']
# ['Darlleen', 'Alcott', '19099571', 'Darlleen.Alcott@college.harvard.edu']
# ['Shauna', 'Dunkin', '17752080', 'Shauna.Dunkin@college.harvard.edu']
# ['Sadie', 'Morgun', '14448844', 'Sadie.Morgun@college.harvard.edu']
# ['Celestyna', 'Bennie', '18135448', 'Celestyna.Bennie@college.harvard.edu']
# ['June', 'Nisbet', '14808539', 'June.Nisbet@college.harvard.edu']
# ['Kelly', 'Larochelle', '13560035', 'Kelly.Larochelle@college.harvard.edu']
# ['Kerrin', 'Merat', '12449723', 'Kerrin.Merat@college.harvard.edu']
# ['Sherrie', 'Brenn', '18386637', 'Sherrie.Brenn@college.harvard.edu']
# ['Dulce', 'Hoban', '16394788', 'Dulce.Hoban@college.harvard.edu']
# ['Marti', 'Garlinda', '14768316', 'Marti.Garlinda@college.harvard.edu']
# ['Amelia', 'Westphal', '18233684', 'Amelia.Westphal@college.harvard.edu']
# ['Sarette', 'Albertine', '14845125', 'Sarette.Albertine@college.harvard.edu']
# ['Cindelyn', 'Holbrook', '12951408', 'Cindelyn.Holbrook@college.harvard.edu']
# ['Ginnie', 'Shelba', '17277163', 'Ginnie.Shelba@college.harvard.edu']
# ['Susan', 'Vittoria', '13986225', 'Susan.Vittoria@college.harvard.edu']
# ['Sissy', 'Anestassia', '10159636', 'Sissy.Anestassia@college.harvard.edu']
# ['Cassandra', 'Durante', '19700216', 'Cassandra.Durante@college.harvard.edu']
# ['Cathie', 'Stover', '10070624', 'Cathie.Stover@college.harvard.edu']
# ['Charissa', 'Celestine', '19960389', 'Charissa.Celestine@college.harvard.edu']
# ['Fred', 'Malina', '11351426', 'Fred.Malina@college.harvard.edu']
# ['Marita', 'Linehan', '19612251', 'Marita.Linehan@college.harvard.edu']
# ['Lorenza', 'Zenas', '15456782', 'Lorenza.Zenas@college.harvard.edu']
# ['Drucie', 'Karylin', '18703631', 'Drucie.Karylin@college.harvard.edu']
# ['Nerta', 'Modie', '11532864', 'Nerta.Modie@college.harvard.edu']
# ['Claudina', 'Durware', '18346597', 'Claudina.Durware@college.harvard.edu']
# ['Andree', 'Roche', '19632846', 'Andree.Roche@college.harvard.edu']
# ['Nadine', 'Kosey', '17956930', 'Nadine.Kosey@college.harvard.edu']
# ['Laure', 'Oscar', '12525371', 'Laure.Oscar@college.harvard.edu']
# ['Tierney', 'Wu', '19390579', 'Tierney.Wu@college.harvard.edu']
# ['Dari', 'Paton', '15473564', 'Dari.Paton@college.harvard.edu']
# ['Viviene', 'Peg', '12383317', 'Viviene.Peg@college.harvard.edu']
# ['Emma', 'Braun', '16996166', 'Emma.Braun@college.harvard.edu']
# ['Mathilda', 'Henrie', '12978721', 'Mathilda.Henrie@college.harvard.edu']
# ['Romona', 'Merna', '15036450', 'Romona.Merna@college.harvard.edu']
# ['Jere', 'Toffic', '11539889', 'Jere.Toffic@college.harvard.edu']
# ['Marinna', 'Parette', '16140510', 'Marinna.Parette@college.harvard.edu']
# ['Ketti', 'Tiffa', '15469152', 'Ketti.Tiffa@college.harvard.edu']
# ['Harmonia', 'Carri', '12627315', 'Harmonia.Carri@college.harvard.edu']
# ['Sadie', 'Isidore', '18358708', 'Sadie.Isidore@college.harvard.edu']
# ['Rani', 'Suk', '18378409', 'Rani.Suk@college.harvard.edu']
# ['Evaleen', 'Cassius', '14474086', 'Evaleen.Cassius@college.harvard.edu']
# ['Kial', 'Mott', '15236360', 'Kial.Mott@college.harvard.edu']
# ['Vere', 'Gibbeon', '19183260', 'Vere.Gibbeon@college.harvard.edu']
# ['Mireielle', 'Bury', '14284381', 'Mireielle.Bury@college.harvard.edu']
# ['Susette', 'Tillford', '15143150', 'Susette.Tillford@college.harvard.edu']
# ['Edith', 'Mehalek', '10740566', 'Edith.Mehalek@college.harvard.edu']
# ['Yolane', 'Modie', '11562119', 'Yolane.Modie@college.harvard.edu']
# ['Maud', 'Faust', '16110589', 'Maud.Faust@college.harvard.edu']
# ['Siana', 'Ciapas', '16454736', 'Siana.Ciapas@college.harvard.edu']
# ['Berget', 'Zamora', '16516619', 'Berget.Zamora@college.harvard.edu']
# ['Gilligan', 'Hanshaw', '14960727', 'Gilligan.Hanshaw@college.harvard.edu']
# ['Nelle', 'Thar', '11408415', 'Nelle.Thar@college.harvard.edu']
# ['Frank', 'Riordan', '18399516', 'Frank.Riordan@college.harvard.edu']
# ['Kirstin', 'Ruvolo', '10796580', 'Kirstin.Ruvolo@college.harvard.edu']
# ['Dulcinea', 'Erskine', '10629135', 'Dulcinea.Erskine@college.harvard.edu']
# ['Ivett', "O'Neill", '18808262', "Ivett.O'Neill@college.harvard.edu"]
# ['Constance', 'Hull', '14103313', 'Constance.Hull@college.harvard.edu']
# ['Valera', 'Rooney', '13314483', 'Valera.Rooney@college.harvard.edu']
# ['Sybille', 'Valoniah', '15672703', 'Sybille.Valoniah@college.harvard.edu']
# ['Harmonia', 'Norrie', '17792981', 'Harmonia.Norrie@college.harvard.edu']
# ['Bettine', 'Center', '10020605', 'Bettine.Center@college.harvard.edu']
# ['Raf', 'Strephon', '10878788', 'Raf.Strephon@college.harvard.edu']
# ['Desirae', 'Meli', '12816224', 'Desirae.Meli@college.harvard.edu']
# ['Paulita', 'Saunderson', '11296242', 'Paulita.Saunderson@college.harvard.edu']
# ['Emilia', 'Lipson', '14973202', 'Emilia.Lipson@college.harvard.edu']
# ['Nikki', 'Norrie', '15105613', 'Nikki.Norrie@college.harvard.edu']
# ['Chickie', 'Shanley', '13273260', 'Chickie.Shanley@college.harvard.edu']
# ['Arlina', 'Chabot', '14578894', 'Arlina.Chabot@college.harvard.edu']
# ['Shirlee', 'Harl', '10033912', 'Shirlee.Harl@college.harvard.edu']
# ['Raquela', 'Chaing', '19614740', 'Raquela.Chaing@college.harvard.edu']
# ['Zaria', 'Pascia', '17938606', 'Zaria.Pascia@college.harvard.edu']
# ['Mariann', 'Ellord', '19579544', 'Mariann.Ellord@college.harvard.edu']
# ['Elbertina', 'Clara', '11249526', 'Elbertina.Clara@college.harvard.edu']
# ['Myriam', 'Freddi', '19696593', 'Myriam.Freddi@college.harvard.edu']
# ['Annabela', 'Rodmann', '17433332', 'Annabela.Rodmann@college.harvard.edu']
# ['Letizia', 'Hartnett', '13329529', 'Letizia.Hartnett@college.harvard.edu']
# ['Dulce', 'Toffic', '12831699', 'Dulce.Toffic@college.harvard.edu']
# ['Elbertina', 'Sholley', '19885130', 'Elbertina.Sholley@college.harvard.edu']
# ['Cindelyn', 'Ferrell', '18675179', 'Cindelyn.Ferrell@college.harvard.edu']
# ['Katharina', 'Wu', '12200428', 'Katharina.Wu@college.harvard.edu']
# ['Jenilee', 'Huggins', '11353279', 'Jenilee.Huggins@college.harvard.edu']
# ['Jenilee', 'Ammann', '11561470', 'Jenilee.Ammann@college.harvard.edu']
# ['Annecorinne', 'Vacuva', '12371132', 'Annecorinne.Vacuva@college.harvard.edu']
# ['Penelopa', 'Honoria', '15128348', 'Penelopa.Honoria@college.harvard.edu']
# ['Elie', 'Dearborn', '15995500', 'Elie.Dearborn@college.harvard.edu']
# ...
# ['Corly', 'Harl', '12833842', 'Corly.Harl@college.harvard.edu']
# ['Robbi', 'Suk', '12603456', 'Robbi.Suk@college.harvard.edu']
# ['Vere', 'Barbey', '11460205', 'Vere.Barbey@college.harvard.edu']
# ['Fidelia', 'Martguerita', '13153624', 'Fidelia.Martguerita@college.harvard.edu']
# ['Gerianna', 'My', '12329350', 'Gerianna.My@college.harvard.edu']
# ['Ursulina', 'Deny', '13606343', 'Ursulina.Deny@college.harvard.edu']
# ['Catrina', 'Honoria', '10506474', 'Catrina.Honoria@college.harvard.edu']
# ['Marinna', 'Lubin', '19679778', 'Marinna.Lubin@college.harvard.edu']
# ['Helena', 'Gert', '13275436', 'Helena.Gert@college.harvard.edu']
# ['Dorothy', 'Pandolfi', '19101916', 'Dorothy.Pandolfi@college.harvard.edu']
# ['Kristina', 'Roscoe', '17390121', 'Kristina.Roscoe@college.harvard.edu']
# ['Merry', 'Lunsford', '15030655', 'Merry.Lunsford@college.harvard.edu']
# ['Genevra', 'Rillings', '10949407', 'Genevra.Rillings@college.harvard.edu']
# ['Sherrie', 'Anselmi', '10852333', 'Sherrie.Anselmi@college.harvard.edu']
# ['Vinita', 'Hylan', '12534388', 'Vinita.Hylan@college.harvard.edu']
# ['Ellette', 'Skurnik', '17920533', 'Ellette.Skurnik@college.harvard.edu']
# ['Ginnie', 'Gunn', '15626505', 'Ginnie.Gunn@college.harvard.edu']
# ['Thalia', 'Manolo', '12596752', 'Thalia.Manolo@college.harvard.edu']
# ['Alie', 'Tybald', '14250354', 'Alie.Tybald@college.harvard.edu']
# ['Dawn', 'Stilwell', '17553201', 'Dawn.Stilwell@college.harvard.edu']
# ['Kirstin', 'Johanna', '18037145', 'Kirstin.Johanna@college.harvard.edu']
# ['Nyssa', 'Longfellow', '16028266', 'Nyssa.Longfellow@college.harvard.edu']
# ['Basia', 'Elsinore', '15094239', 'Basia.Elsinore@college.harvard.edu']
# ['Allis', 'Halsey', '15226344', 'Allis.Halsey@college.harvard.edu']
# ['Merry', 'Drus', '12392296', 'Merry.Drus@college.harvard.edu']
# ['Leanna', 'Terencio', '10279646', 'Leanna.Terencio@college.harvard.edu']
# ['Claresta', 'Adlare', '19932243', 'Claresta.Adlare@college.harvard.edu']
# ['Cherilyn', 'Egbert', '11969863', 'Cherilyn.Egbert@college.harvard.edu']
# ['Anestassia', 'Claudine', '11114570', 'Anestassia.Claudine@college.harvard.edu']
# ['Kittie', 'Taima', '12266700', 'Kittie.Taima@college.harvard.edu']
# ['Demetris', 'Bertold', '17777816', 'Demetris.Bertold@college.harvard.edu']
# ['Zondra', 'Shaddock', '10782217', 'Zondra.Shaddock@college.harvard.edu']
# ['Marti', 'Maisey', '17171855', 'Marti.Maisey@college.harvard.edu']
# ['Bee', 'Mallon', '13634956', 'Bee.Mallon@college.harvard.edu']
# ['Dawn', 'Kunin', '12977263', 'Dawn.Kunin@college.harvard.edu']
# ['Emmey', 'Rona', '15608509', 'Emmey.Rona@college.harvard.edu']
# ['Ida', 'Wilkinson', '17300062', 'Ida.Wilkinson@college.harvard.edu']
# ['Dorene', 'Solitta', '16469142', 'Dorene.Solitta@college.harvard.edu']
# ['Audrie', 'Baptlsta', '14111226', 'Audrie.Baptlsta@college.harvard.edu']
# ['Drucie', 'Abram', '15790582', 'Drucie.Abram@college.harvard.edu']
# ['Hollie', 'Teryn', '19937443', 'Hollie.Teryn@college.harvard.edu']
# ['Evaleen', 'Ashely', '15240424', 'Evaleen.Ashely@college.harvard.edu']
# ['Justinn', 'Papageno', '13205422', 'Justinn.Papageno@college.harvard.edu']
# ['Elbertina', 'Pattin', '10850180', 'Elbertina.Pattin@college.harvard.edu']
# ['Abbie', 'Mich', '11327673', 'Abbie.Mich@college.harvard.edu']
# ['Alia', 'Audly', '11579133', 'Alia.Audly@college.harvard.edu']
# ['Mara', 'Clarissa', '16264437', 'Mara.Clarissa@college.harvard.edu']
# ['Aaren', 'Torray', '12031783', 'Aaren.Torray@college.harvard.edu']
# ['Loree', 'Ingra', '18682611', 'Loree.Ingra@college.harvard.edu']
# ['Ursulina', 'Charmine', '17843792', 'Ursulina.Charmine@college.harvard.edu']
# ['Iseabal', 'Land', '15815392', 'Iseabal.Land@college.harvard.edu']
# ['Aryn', 'Yerkovich', '14900582', 'Aryn.Yerkovich@college.harvard.edu']
# ['Allyce', 'Rozanna', '14944069', 'Allyce.Rozanna@college.harvard.edu']
# ['Konstance', 'Talia', '18555352', 'Konstance.Talia@college.harvard.edu']
# ['Brietta', 'Allina', '19861051', 'Brietta.Allina@college.harvard.edu']
# ['Talya', 'Heisel', '15024268', 'Talya.Heisel@college.harvard.edu']
# ['Ketti', 'Cohdwell', '19190297', 'Ketti.Cohdwell@college.harvard.edu']
# ['Malina', 'Bonilla', '10078311', 'Malina.Bonilla@college.harvard.edu']
# ['Thalia', 'McLaughlin', '12937283', 'Thalia.McLaughlin@college.harvard.edu']
# ['Ardeen', 'Nedrud', '11702187', 'Ardeen.Nedrud@college.harvard.edu']
# ['Clary', 'Merat', '11186850', 'Clary.Merat@college.harvard.edu']
# ['Wilma', 'Justinn', '10037489', 'Wilma.Justinn@college.harvard.edu']
# ['Clarice', 'Philoo', '14558528', 'Clarice.Philoo@college.harvard.edu']
# ['Fayre', 'Erich', '15748763', 'Fayre.Erich@college.harvard.edu']
# ['Jan', 'Elsinore', '18874845', 'Jan.Elsinore@college.harvard.edu']
# ['Maisey', 'Torray', '15268100', 'Maisey.Torray@college.harvard.edu']
# ['Priscilla', 'Atcliffe', '10738212', 'Priscilla.Atcliffe@college.harvard.edu']
# ['Fredericka', 'Clara', '15308749', 'Fredericka.Clara@college.harvard.edu']
# ['Myrtice', 'Standing', '19608294', 'Myrtice.Standing@college.harvard.edu']
# ['Pearline', 'Kaja', '14368835', 'Pearline.Kaja@college.harvard.edu']
# ['Natka', 'Ellord', '13481438', 'Natka.Ellord@college.harvard.edu']
# ['Larine', 'Wolfgram', '13603911', 'Larine.Wolfgram@college.harvard.edu']
# ['Juliane', 'Eldrid', '15647241', 'Juliane.Eldrid@college.harvard.edu']
# ['Nannie', 'Doig', '11796401', 'Nannie.Doig@college.harvard.edu']
# ['Ursulina', 'Belanger', '18234916', 'Ursulina.Belanger@college.harvard.edu']
# ['Kamilah', 'Dex', '17490516', 'Kamilah.Dex@college.harvard.edu']
# ['Rebeca', 'Cullin', '14775995', 'Rebeca.Cullin@college.harvard.edu']
# ['Charlena', 'Curren', '14208326', 'Charlena.Curren@college.harvard.edu']
# ['Maurene', 'Reneta', '15341215', 'Maurene.Reneta@college.harvard.edu']
# ['Adore', 'Ferrell', '14330046', 'Adore.Ferrell@college.harvard.edu']
# ['Celene', 'Flita', '14264948', 'Celene.Flita@college.harvard.edu']
# ['Sara-Ann', 'Granoff', '15624180', 'Sara-Ann.Granoff@college.harvard.edu']
# ['Alejandra', 'Goldina', '14849367', 'Alejandra.Goldina@college.harvard.edu']
# ['Barbara', 'Izaak', '11720047', 'Barbara.Izaak@college.harvard.edu']
# ['Dagmar', 'Ralfston', '12534837', 'Dagmar.Ralfston@college.harvard.edu']
# ['Bobinette', 'Gale', '16366790', 'Bobinette.Gale@college.harvard.edu']
# ['Deirdre', 'Chrystel', '18986651', 'Deirdre.Chrystel@college.harvard.edu']
# ['Joane', 'Clarissa', '14867505', 'Joane.Clarissa@college.harvard.edu']
# ['Luci', 'Hartnett', '14353282', 'Luci.Hartnett@college.harvard.edu']
# ['Tybie', 'Elo', '19894264', 'Tybie.Elo@college.harvard.edu']
# ['Farrah', 'Ariella', '18022796', 'Farrah.Ariella@college.harvard.edu']
# ['Rivalee', 'Dom', '18569603', 'Rivalee.Dom@college.harvard.edu']
# ['Etta', 'Darbie', '10556917', 'Etta.Darbie@college.harvard.edu']
# ['Aeriela', 'Colbert', '16741827', 'Aeriela.Colbert@college.harvard.edu']
# ['Brooks', 'Korey', '11114508', 'Brooks.Korey@college.harvard.edu']
# ['Pollyanna', 'Paton', '15252559', 'Pollyanna.Paton@college.harvard.edu']
# ['Emelina', 'Hachmin', '18917186', 'Emelina.Hachmin@college.harvard.edu']
# ['Lelah', 'Raychel', '13536372', 'Lelah.Raychel@college.harvard.edu']
# ['Joy', 'Dielu', '16119039', 'Joy.Dielu@college.harvard.edu']
# ['Britni', 'Tybald', '10439068', 'Britni.Tybald@college.harvard.edu']
# ['Gerrie', 'Morrill', '14919551', 'Gerrie.Morrill@college.harvard.edu']
# ['Kayla', 'Hachmin', '10673577', 'Kayla.Hachmin@college.harvard.edu']
# ['Aurore', 'Martsen', '18671855', 'Aurore.Martsen@college.harvard.edu']
# ['Miquela', 'Keelia', '13632942', 'Miquela.Keelia@college.harvard.edu']
# ['Talya', 'Lynn', '15487456', 'Talya.Lynn@college.harvard.edu']
# ['Mallory', 'Ajay', '11476841', 'Mallory.Ajay@college.harvard.edu']
# ['Nariko', 'Marsden', '11707944', 'Nariko.Marsden@college.harvard.edu']
# ['Quintina', 'Ralfston', '10073376', 'Quintina.Ralfston@college.harvard.edu']
# ['Fawne', 'Sigfrid', '11903270', 'Fawne.Sigfrid@college.harvard.edu']
# ['Kore', 'Freddi', '19662289', 'Kore.Freddi@college.harvard.edu']
# ['Jan', 'Liva', '16093870', 'Jan.Liva@college.harvard.edu']
# ['Jorry', 'Stilwell', '19574470', 'Jorry.Stilwell@college.harvard.edu']
# ['Ileana', 'Erlandson', '17180867', 'Ileana.Erlandson@college.harvard.edu']
# ['Marti', 'Orpah', '12030548', 'Marti.Orpah@college.harvard.edu']
# ['Nelle', 'Erich', '13451313', 'Nelle.Erich@college.harvard.edu']
# ['Carly', 'Danby', '19758688', 'Carly.Danby@college.harvard.edu']
# ['Ileana', 'Eno', '15411773', 'Ileana.Eno@college.harvard.edu']
# ['Tobe', 'Luhe', '19471335', 'Tobe.Luhe@college.harvard.edu']
# ['Goldie', 'Sisile', '14414869', 'Goldie.Sisile@college.harvard.edu']
# ['Allis', 'Couture', '18620374', 'Allis.Couture@college.harvard.edu']
# ['Rhoda', 'Gale', '14088915', 'Rhoda.Gale@college.harvard.edu']
# ['Kristan', 'Newell', '19604869', 'Kristan.Newell@college.harvard.edu']
# ['Lynde', 'Olympium', '11052779', 'Lynde.Olympium@college.harvard.edu']
# ['Chandra', 'Garlinda', '16932813', 'Chandra.Garlinda@college.harvard.edu']
# ['Lila', 'Sinegold', '19159524', 'Lila.Sinegold@college.harvard.edu']
# ['Frank', 'Kathie', '16862194', 'Frank.Kathie@college.harvard.edu']
# ['Paulita', 'Ogren', '13497189', 'Paulita.Ogren@college.harvard.edu']
# ['Clarice', 'Joli', '12851512', 'Clarice.Joli@college.harvard.edu']
# ['Concettina', 'Bohlin', '13186776', 'Concettina.Bohlin@college.harvard.edu']
# ['Jasmina', 'Joeann', '17828548', 'Jasmina.Joeann@college.harvard.edu']
# ['Tera', 'McLaughlin', '11154176', 'Tera.McLaughlin@college.harvard.edu']
# ['Lynde', 'Judye', '13912241', 'Lynde.Judye@college.harvard.edu']
# ['Ingrid', 'Eachern', '12490247', 'Ingrid.Eachern@college.harvard.edu']
# ['Melanie', 'Chinua', '14492121', 'Melanie.Chinua@college.harvard.edu']
# ['Myriam', 'Cordi', '15070777', 'Myriam.Cordi@college.harvard.edu']
# ['Karolina', 'Suzetta', '16865470', 'Karolina.Suzetta@college.harvard.edu']
# ['Betta', 'Wallis', '13059662', 'Betta.Wallis@college.harvard.edu']
# ['Paulita', 'Felizio', '12402678', 'Paulita.Felizio@college.harvard.edu']
# ['Leeanne', 'Monaco', '17596570', 'Leeanne.Monaco@college.harvard.edu']
# ['Latisha', 'Verger', '19686138', 'Latisha.Verger@college.harvard.edu']
# ['Aryn', 'Crudden', '18626775', 'Aryn.Crudden@college.harvard.edu']
# ['Cathie', 'Bettine', '12998855', 'Cathie.Bettine@college.harvard.edu']
# ['Tilly', 'Raffo', '14504872', 'Tilly.Raffo@college.harvard.edu']
# ['Robinia', 'Larochelle', '16935466', 'Robinia.Larochelle@college.harvard.edu']
# ['Teriann', 'Raseda', '13881261', 'Teriann.Raseda@college.harvard.edu']
# ['Etta', 'Girardo', '13042891', 'Etta.Girardo@college.harvard.edu']
# ['Danika', 'Nunci', '19294671', 'Danika.Nunci@college.harvard.edu']
# ['Elora', 'Haerr', '11676178', 'Elora.Haerr@college.harvard.edu']
# ['Sheelagh', 'Adamsen', '18459894', 'Sheelagh.Adamsen@college.harvard.edu']
# ['Britte', 'Baudin', '10787024', 'Britte.Baudin@college.harvard.edu']
# ['Justinn', 'Shaddock', '11087272', 'Justinn.Shaddock@college.harvard.edu']
# ['Suzette', 'Etom', '18230466', 'Suzette.Etom@college.harvard.edu']
# ['Fina', 'Hoban', '19667123', 'Fina.Hoban@college.harvard.edu']
# ['Noelle', 'Mozelle', '12677312', 'Noelle.Mozelle@college.harvard.edu']
# ['Jsandye', 'Raseda', '10487563', 'Jsandye.Raseda@college.harvard.edu']
# ['Courtnay', 'Johnsson', '19747366', 'Courtnay.Johnsson@college.harvard.edu']
# ['Lanna', 'Kaja', '10324447', 'Lanna.Kaja@college.harvard.edu']
# ['Margette', 'Boehike', '17049726', 'Margette.Boehike@college.harvard.edu']
# ['Phylis', 'Koehler', '16551520', 'Phylis.Koehler@college.harvard.edu']
# ['Gretal', 'Carvey', '12341371', 'Gretal.Carvey@college.harvard.edu']
# ['Latisha', 'Even', '18843429', 'Latisha.Even@college.harvard.edu']
# ['Althea', 'Deegan', '12802873', 'Althea.Deegan@college.harvard.edu']
# ['Fanny', 'Peg', '12661749', 'Fanny.Peg@college.harvard.edu']
# ['Arabel', 'Dalli', '18867335', 'Arabel.Dalli@college.harvard.edu']
# ['Sallie', 'Tjon', '17702318', 'Sallie.Tjon@college.harvard.edu']
# ['Elyssa', 'Zuzana', '16973517', 'Elyssa.Zuzana@college.harvard.edu']
# ['Luci', 'Myrilla', '18165262', 'Luci.Myrilla@college.harvard.edu']
# ['Ketti', 'Yorick', '14552309', 'Ketti.Yorick@college.harvard.edu']
# ['Julieta', 'Remmer', '10462950', 'Julieta.Remmer@college.harvard.edu']
# ['Mathilda', 'Japeth', '19845330', 'Mathilda.Japeth@college.harvard.edu']
# ['Liana', 'Redmond', '12845395', 'Liana.Redmond@college.harvard.edu']
# ['Regina', 'Rodmann', '17836189', 'Regina.Rodmann@college.harvard.edu']
# ['Ariela', 'Robertson', '14099607', 'Ariela.Robertson@college.harvard.edu']
# ['Elise', 'Adalbert', '13637858', 'Elise.Adalbert@college.harvard.edu']
# ['Talya', 'Ciapas', '10195951', 'Talya.Ciapas@college.harvard.edu']
# ['Merrie', 'Ivens', '17807279', 'Merrie.Ivens@college.harvard.edu']
# ['Elise', 'Kellby', '12101108', 'Elise.Kellby@college.harvard.edu']
# ['Ekaterina', 'Donoghue', '10558401', 'Ekaterina.Donoghue@college.harvard.edu']
# ['Annecorinne', 'Cecile', '13506041', 'Annecorinne.Cecile@college.harvard.edu']
# ['Joelly', 'Isacco', '15612284', 'Joelly.Isacco@college.harvard.edu']
# ['Jobi', 'Creamer', '18169826', 'Jobi.Creamer@college.harvard.edu']
# ['Genovera', 'Alexandr', '13576426', 'Genovera.Alexandr@college.harvard.edu']
# ['Dolli', 'Euridice', '14268919', 'Dolli.Euridice@college.harvard.edu']
# ['Elka', 'Haldas', '10629376', 'Elka.Haldas@college.harvard.edu']
# ['Shell', 'Phaidra', '13136613', 'Shell.Phaidra@college.harvard.edu']
# ['Liana', 'Lissi', '13911474', 'Liana.Lissi@college.harvard.edu']
# ['Robinia', 'Ellord', '10742371', 'Robinia.Ellord@college.harvard.edu']
# ['Adelle', 'Nea', '13071744', 'Adelle.Nea@college.harvard.edu']
# ['Sidoney', 'Etom', '11008621', 'Sidoney.Etom@college.harvard.edu']
# ['Marguerite', 'Ardeha', '19849461', 'Marguerite.Ardeha@college.harvard.edu']
# ['Tina', 'Isidore', '10302738', 'Tina.Isidore@college.harvard.edu']
# ['Nikki', 'Bobbee', '16133910', 'Nikki.Bobbee@college.harvard.edu']
# ['Monika', 'Gilbertson', '17032612', 'Monika.Gilbertson@college.harvard.edu']
# ['Desirae', 'Sholley', '19475426', 'Desirae.Sholley@college.harvard.edu']
# ['Bertine', 'Avi', '15189854', 'Bertine.Avi@college.harvard.edu']
# ['Charissa', 'Garrison', '10164177', 'Charissa.Garrison@college.harvard.edu']
# ['Ayn', 'Yuille', '14836415', 'Ayn.Yuille@college.harvard.edu']
# ['Heida', 'Colleen', '11451119', 'Heida.Colleen@college.harvard.edu']
# ['Kary', 'Hurley', '19259148', 'Kary.Hurley@college.harvard.edu']
# ['Nita', 'Engdahl', '12930901', 'Nita.Engdahl@college.harvard.edu']
# ['Catrina', 'Adlare', '14406501', 'Catrina.Adlare@college.harvard.edu']
# ['Nicoli', 'Sholley', '17218018', 'Nicoli.Sholley@college.harvard.edu']
# ['Jacquetta', 'McAdams', '11054765', 'Jacquetta.McAdams@college.harvard.edu']
# ['Anica', 'Redmond', '16156205', 'Anica.Redmond@college.harvard.edu']
# ['Cathyleen', 'Sholley', '16958010', 'Cathyleen.Sholley@college.harvard.edu']
# ['Lonnie', 'Blisse', '14330413', 'Lonnie.Blisse@college.harvard.edu']
# ['Imojean', 'Rad', '13287914', 'Imojean.Rad@college.harvard.edu']
# ['Gaylene', 'Chandler', '12192844', 'Gaylene.Chandler@college.harvard.edu']
# ['Dyann', 'Martguerita', '11819882', 'Dyann.Martguerita@college.harvard.edu']
# ['Renae', 'Wittie', '14464888', 'Renae.Wittie@college.harvard.edu']
# ['Viki', 'Lucienne', '11379809', 'Viki.Lucienne@college.harvard.edu']
# ['Atlanta', 'Ax', '12834470', 'Atlanta.Ax@college.harvard.edu']
# ['Angelique', 'Briney', '14065940', 'Angelique.Briney@college.harvard.edu']
# ['Jeanna', 'Gordon', '18251154', 'Jeanna.Gordon@college.harvard.edu']
# ['Lynea', 'Israeli', '17410167', 'Lynea.Israeli@college.harvard.edu']
# ['Judy', 'Merell', '10991251', 'Judy.Merell@college.harvard.edu']
# ['Jillayne', 'Gillan', '13366343', 'Jillayne.Gillan@college.harvard.edu']
# ['Vevay', 'Timon', '13203250', 'Vevay.Timon@college.harvard.edu']
# ['Orsola', 'Genna', '17089264', 'Orsola.Genna@college.harvard.edu']
# ['Kalina', 'Carlson', '19727831', 'Kalina.Carlson@college.harvard.edu']
# ['Millie', 'Reidar', '17097091', 'Millie.Reidar@college.harvard.edu']
# ['Kate', 'Selway', '11613307', 'Kate.Selway@college.harvard.edu']
# ['Marsiella', 'Edmund', '17939908', 'Marsiella.Edmund@college.harvard.edu']
# ['Gretal', 'Muriel', '17593926', 'Gretal.Muriel@college.harvard.edu']
# ['Gilda', 'Brieta', '11581271', 'Gilda.Brieta@college.harvard.edu']
# ['Deane', 'Faria', '18144500', 'Deane.Faria@college.harvard.edu']

# %%
# example - generate a random integer between 1 and 10.
example_random = random.randint(1,10)
print(example_random)
# Out:
# 10

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# Your turn - load the csv file, create a random number for each student between 0-11 and store all students in a new csv file with their respective house assignments. A for loop might come in handy.

# %%
# your code here

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# Write a small program that makes sure that you've successfully created and populated a csv with all students and their assigned houses.

# %%
# your code here

# %% [markdown]
# <div style='background: #ADCAD6; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Task #2 - generate a file for a house on demand
#
# OK, you've helped the college out with the lottery but now the house administrators are struggling a bit because they have all 2000 students in one file but only care about the students that were assigned to their particular house. Write a small programm that solves that task on demand and generates a csv for them with only their students. You can write a program that does this task on demand for a given house, or you can generate a csv for each house in advance.

# %%
# your code here

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>
#
# ## Bonus Tasks
#
# 1. calculate vacant rooms per house
# 2. write a program that computes the number of students assigned per house in a given csv
# 3. write a function that checks whether there are problems with the numbers of students assigned to each house
# 4. write code that assigns students randomly but in such a way that there are no capacity issues.

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>
# Some house administrators have complaned that the list of students is too long to accomodate all new sophomores assigned to their houses. Since some houses are bigger and others are smaller, we cannot simply generate integers and get away with the randomly generated number of students in each house. Rather, we have to check more carefolly whether there is still capacity. Below, find two useful dictionaries hat should help you to solve this task.

# %%
# bonus is house with exact capacities

house_capacity = {
    'Adams House': 411,
    'Cabot House': 362,
    'Currier House' : 356,
    'Dunster House': 428,
    'Eliot House': 450,
    'Kirkland House': 400,
    'Leverett House': 480,
    'Lowell House': 450,
    'Mather House': 426,
    'Pforzheimer House':360,
    'Quincy House': 420,
    'Winthrop House': 500
}

# number of occupied rooms after seniors have left
house_occupied = {
    'Adams House': 236,
    'Cabot House': 213,
    'Currier House' : 217,
    'Dunster House': 296,
    'Eliot House': 288,
    'Kirkland House': 224,
    'Leverett House': 233,
    'Lowell House': 242,
    'Mather House': 217,
    'Pforzheimer House':195,
    'Quincy House': 253,
    'Winthrop House': 310
}

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>Let's start by writing a small program that helps us to calculate the vacant rooms for each house. Try to use a dictionary structure that contains all information for each house. Feel free to also write a few lines that check how many vacant rooms there are in total.

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>Let's now write a small function that calculates the number of students assigned per house with our old method and returns a dictionary with that information

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>Next, let's check by how much we were off for each house with our random approach.

# %% [markdown]
# <div style='background: #CBE0A4; padding: 10px; border: thin solid darblue; border-radius: 5px'>Finally, let's write a function that assignes houses more carefully. We can still generate random integers to assign a house, but we need to check whether that house still has capacity. For that reason, please create a function called assign_house() that generates not only a random number, but also checks whether that number is valid, i.e. if that house still has capacity. If there's no capacity, that function should call itself again until it generates a house (id) that still has capacity.
